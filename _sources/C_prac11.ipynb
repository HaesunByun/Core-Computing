# %% [markdown]
# # 실습 WEEK11: 탐색

# %% [markdown]
# :::{admonition} 안내
# :class: info
#
# - 실습 문제는 사전, 도전, 완전 실습 문제로 구성되어 있습니다.
# - 사전 실습 문제는 수업 전에 미리 풀어보시면 도움이 됩니다.
# - **<font color='blue'>도전 실습 문제는 etl>우리강좌>코딩수업>에 접속한 후, 해당 주차 문제의 소스코드를 제출하여 테스트를 통과해야 과제 점수를 받을 수 있습니다.</font>**
# - **<font color='red'>제출기한은 실습수업시간부터 다음 실습수업 전날 자정까지</font>**입니다.
# - 완전 실습 문제는 보너스 실습 문제로 생각하시면 됩니다.  도전 실습 문제를 다 풀어본 학생들이 추가적으로 풀어보시면 도움이 됩니다.
# - 사전 실습 문제와 완전 실습 문제는 수업 시간에 별도 풀이를 하지 않습니다.
# - 질문은 사전, 도전, 완전 그리고 수업과 관련된 모든 것에  대하여 교수자 or 조교 or 튜터에게 하시면 됩니다.
# - **<font color='red'>가독성을 위해 입출력 데이터에서 콜론(:) 다음에는 항상 한칸 공백이 있습니다.</font>**
#
# :::

# %% [markdown]
# ### 데이터 입력과 출력 예
# 😄문자열을 입력받아 출력하시오.
#
# ---
#
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# 즐거워
# ```
# Output Sample
# ```
# 문자열:
# 출력결과: 즐거워
# ```
#
#
# <font color='blue'>`test case-2`</font>
#
# Input Sample
# ```
# Say! I can do it!
# ```
# Output Sample
# ```
# 문자열:
# 출력결과: Say! I can do it!
# ```

# %%
input_data = input('문자열: ')
print(f'출력결과: {input_data}')
# Out:
# 문자열: Say! I can do it!
# 출력결과: Say! I can do it!

# %% [markdown]
# ## [사전 실습 문제]

# %% [markdown]
# ### Problem: 학생이름찾기1◼◼◻◻◻
# 😄 다음과 같이 학생 번호와 이름이 리스트로 주어졌을 때 학생 번호를 입력하면 학생번호를 순차 탐색으로 찾아 학생번호에 해당하는 이름을 반환하는 함수를 만드시오. 해당하는 학생 번호가 없으면 물음표(?)를 반환합니다.
#
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# 62
# ```
#
# Output Sample
# ```
# Student Number:
# jin
# ```
# <font color='blue'>`test case-2`</font>
#
# Input Sample
# ```
# 102
# ```
#
# Output Sample
# ```
# Student Number:
# ?
# ```

# %%
stu_no = [62, 3, 17, 90, 46, 67, 11, 24, 33, 69]
stu_name = ['jin', 'su', 'young', 'sun', 'yejin', 'rang', 'bok','iyou', 'seok','seul']

# %% [markdown]
# ### Problem: 학생이름찾기2◼◼◻◻◻
# 😄 다음과 같이 학생 번호와 이름이 딕셔너리로 주어졌을 때 학생 번호를 입력하면 학생 번호를 순차 탐색으로 찾아 학생번호에 해당하는 이름을 돌려주는 함수를 만드시오. 해당하는 학생 번호가 없으면 물음표(?)를 반환합니다.
#
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# 62
# ```
#
# Output Sample
# ```
# Student Number:
# jin
# ```
# <font color='blue'>`test case-2`</font>
#
# Input Sample
# ```
# 102
# ```
#
# Output Sample
# ```
# Student Number:
# ?
# ```

# %%
stu_dict={62: 'jin', 3: 'su', 17: 'young', 90: 'sun', 46: 'yejin', 67: 'rang', 11: 'bok', 24: 'iyou', 33: 'seok', 69: 'seul'}

# %% [markdown]
# ## [도전 실습 문제-함께 풀어보는 문제]

# %% [markdown]
# ### Problem. 동점인원 구하기◼◼◻◻◻
# 😄 주어진 리스트에 점수가 정렬되어 있다. 동점인원을 구하여 딕셔너리로 반환하는 SameScore()함수를 작성하시오.
#
# <font color='blue'> Test Case-1</font>
#
# Output Sample
# ```
# 동점딕셔너리: {61: 2, 63: 1, 69: 4, 70: 2, 71: 3, 73: 1, 75: 1, 77: 2, 79: 1, 96: 1, 97: 1, 98: 1}
# ```

# %%
scores=[61, 61, 63, 69, 69, 69, 69, 70, 70, 71, 71, 71, 73, 75, 77, 77, 79, 96, 97, 98]

# %% [markdown]
# ### Problem. 천정함수◼◼◼◻◻
# 😄 천정함수란 $\lceil x \rceil$와 같이 표기한다. $x$가 정수인 경우,
# $\lceil x \rceil$ = $x$이며,
# $x$가 정수가 아닌 경우,
# $x$의 바로 위쪽에 있는 정수값, 다른 말로 천정값을 취한다. 즉, $x$ 이상의 정수값 중 가장 작은 정수값을 말한다. 예를 들어, [1,3,6,8]과 같이 리스트가 있을 때 $\lceil 4.7 \rceil$ = $6$이며, $\lceil 8 \rceil$ = $8$이다. 천정값을 이진탐색으로 찾는 CeilBSearch() 함수를 정의하시오.
#
# <font color='blue'> Test Case-1</font>
#
# Input Sample
# ```
# 3.6
# ```
# Output Sample
# ```
# Input Number:
# Ceil(3.6) = 4
# ```
# <font color='blue'> Test Case-2</font>
#
# Input Sample
# ```
# 95.2
# ```
# Output Sample
# ```
# Input Number:
# Ceil(95.2) = -1
# ```
#
# <font color='blue'> Test Case-3</font>
#
# Input Sample
# ```
# 56.6
# ```
# Output Sample
# ```
# Input Number:
# Ceil(56.6) = 57
# ```
#
# <font color='blue'> Test Case-4</font>
#
# Input Sample
# ```
# 62
# ```
# Output Sample
# ```
# Input Number:
# Ceil(62) = 62
# ```

# %%
data=[4, 6, 9, 17, 23, 30, 36, 42, 44, 47, 50, 56, 56, 57, 62, 64, 68, 89, 90, 95]

# %% [markdown]
# ## [도전 실습 문제-스스로 풀어보는 문제]

# %% [markdown]
# ### Problem. 바닥함수◼◼◼◻◻
# 😄 바닥함수란
# $\lfloor x \rfloor$와 같이 표기한다. $x$가 정수인 경우, $\lfloor x \rfloor$ = $x$이며
# $x$가 정수가 아닌 경우, $x$의 바로 아래쪽에 있는 정수값, 다른 말로 바닥값을 취한다. 즉,
# $x$ 이하의 정수값 중 최대 정수값을 의미한다.
#
# 예를 들어, [1,3,6,8]과 같이 리스트가 있을 때 $\lfloor 2.5 \rfloor$ = $1$이며, $\lceil 6 \rceil$ = $6$이다.
#
# 바닥값을 이진탐색으로 찾는 FloorBSearch() 함수를 정의하시오.
#
# <font color='blue'> Test Case-1</font>
#
# Input Sample
# ```
# 3.6
# ```
# Output Sample
# ```
# Input Number:
# Floor(3.6) = -1
# ```
# <font color='blue'> Test Case-2</font>
#
# Input Sample
# ```
# 95.2
# ```
# Output Sample
# ```
# Input Number:
# Floor(95.2) = 95
# ```
#
# <font color='blue'> Test Case-3</font>
#
# Input Sample
# ```
# 56.6
# ```
# Output Sample
# ```
# Input Number:
# Floor(56.6) = 56
# ```
#
# <font color='blue'> Test Case-4</font>
#
# Input Sample
# ```
# 62
# ```
# Output Sample
# ```
# Input Number:
# Floor(62) = 62
# ```

# %%
data=[4, 6, 9, 17, 23, 30, 36, 42, 44, 47, 50, 56, 56, 57, 62, 64, 68, 89, 90, 95]

# %% [markdown]
# ### Problem. 학점매기기◼◼◼◼◻
# 😄 학생들의 이름과 점수가 딕셔너리 형태로 주어집니다. 이 딕셔너리는 점수의 오름차순으로 정렬되어 있습니다.
# 입력받은 학생을 이진탐색으로 검색하고 그 학생의 등수에 따라 학점을 출력하는 프로그램을 작성하시오.
#
# 학점 기준은 다음과 같습니다.
# - int(3/10*전체학생수)의 등수까지 A
# - int(6/10*전체학생수)의 등수까지 B
# - 나머지는 C
# * 동점에 상관없이 등수를 구하면 됩니다.
#
# <font color='blue'> Test Case-1</font>
#
# Input Sample
# ```
# {"지형":55,"윤수":56,"윤호":58,"재우":60,"선우":62,"가희":65,"나희":68,"다희":71,"라희":74,"마희":75,"바희":78,"사희":82,"아희":86,"자희":90}
# 지형
# ```
# Output Sample
# ```
# Input Data:
# Student Name:
# C
# ```
#
# Input Sample
# ```
# {"지형":55,"윤수":58,"윤호":58,"재우":60,"선우":62,"가희":82,"나희":82,"다희":82,"라희":82,"마희":82,"바희":82,"사희":82,"아희":86,"자희":90}
# 가희
# ```
# Output Sample
# ```
# Input Data:
# Student Name:
# A
# ```

# %% [markdown]
# ## [완전 실습 문제]

# %% [markdown]
# ### Problem. 나무자르기◼◼◼◻◻
# 😄 높이를 지정하면 톱날이 땅으로부터 H미터 위로 올라가는 목재절단기가 있다. 그다음 한줄로 연속해 있는 나무를 절단한다. 높이가 H보다 큰 나무는 H위의 부분이 절단되고, 낮은 나무는 잘리지 않을 것이다. 예를 들어, 한줄로 연속해 있는 나무의 길이(M)가 20, 15, 10, 17이고 목재절단기의 높이 H를 15로 지정했다면, 나무를 자른 뒤의 길이는 15, 15, 10, 15가 된다. 즉 길이가 5M인 나무토막과 길이가 2M인 나무토막이 생겨 총 7M의 나무토막이 생긴다.
#
# M미터의 나무를 집에 가져가기 위해서 목재절단기에 설정할 수 있는 높이의 최댓값을 구하는 프로그램을 작성하시오.(자른 나무의 토막들의 총 합이 집으로 가져가려는 나무의 길이와 같아야 한다.)
#
#
# 첫째 줄에 집으로 가져가려는 나무의 길이 M이 주어진다.
#
# 둘째 줄에는 나무의 길이가 주어진다. 나무의 길이의 합은 항상 M보다 크거나 같다.
#
# <font color='blue'> Test Case-1</font>
#
# Input Sample
# ```
# 7
# 20 15 10 17
# ```
# Output Sample
# ```
# Input M:
# Input tree length:
# Height: 15
# ```
#
# Input Sample
# ```
# 20
# 4 42 40 26 46
# ```
# Output Sample
# ```
# Input M:
# Input tree length:
# Height: 36
# ```
