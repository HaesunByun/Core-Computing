# %% [markdown]
# # 실습 WEEK7: 중간고사 대비 문제풀이

# %% [markdown]
# :::{admonition} 안내
# :class: info
#
# - 실습 문제는 사전, 도전, 완전 실습 문제로 구성되어 있습니다.
# - 사전 실습 문제는 수업 전에 미리 풀어보시면 도움이 됩니다.
# - **<font color='blue'>도전 실습 문제는 etl>우리강좌>코딩수업>에 접속한 후, 해당 주차 문제의 소스코드를 제출하여 테스트를 통과해야 과제 점수를 받을 수 있습니다.</font>**
# - **<font color='red'>제출기한은 실습수업시간부터 다음 실습수업 전날 자정까지</font>**입니다.
# - 완전 실습 문제는 보너스 실습 문제로 생각하시면 됩니다.  도전 실습 문제를 다 풀어본 학생들이 추가적으로 풀어보시면 도움이 됩니다.
# - 사전 실습 문제와 완전 실습 문제는 수업 시간에 별도 풀이를 하지 않습니다.
# - 질문은 사전, 도전, 완전 그리고 수업과 관련된 모든 것에  대하여 교수자 or 조교 or 튜터에게 하시면 됩니다.
# - **<font color='red'>가독성을 위해 입출력 데이터에서 콜론(:) 다음에는 항상 한칸 공백이 있습니다.</font>**
#
# :::

# %% [markdown]
# ### 데이터 입력과 출력 예
# 😄문자열을 입력받아 출력하시오.
#
# ---
#
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# 즐거워
# ```
# Output Sample
# ```
# 문자열:
# 출력결과: 즐거워
# ```
#
#
# <font color='blue'>`test case-2`</font>
#
# Input Sample
# ```
# Say! I can do it!
# ```
# Output Sample
# ```
# 문자열:
# 출력결과: Say! I can do it!
# ```

# %%
input_data = input('문자열: ')
print(f'출력결과: {input_data}')
# Out:
# 문자열: Say! I can do it!
# 출력결과: Say! I can do it!

# %% [markdown]
# ## [도전 실습 문제-함께 풀어보는 문제]

# %% [markdown]
# **시험에서 출력결과가 Output Sample과 동일하게 나와 점수를 획득했을지라도 문제에서 제시한대로 코딩하지 않았다면 감점이 있습니다. 예를 들어,**
# - '입출력은 함수 밖에서 이루어집니다.' 구문과 달리 함수 안에서 입출력한 경우,
# - 함수를 정의하라는 제시와 달리 정의하지 않은 경우,
# - 반환 타입이 일치하지 않은 경우, 등

# %% [markdown]
# ### Problem: 단어길이 딕셔너리 만들기◼◻◻◻◻
# 😄영어 문장을 입력받아서 영어 문장에 포함된 단어들의 길이와 개수를 구해서 딕셔너리 형태로 반환하는 함수 count_word_length()를 작성하시오.
#
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# The quick brown fox jumps over the lazy dog
# ```
#
# Output Sample
# ```
# Input: {'3': 4, '5': 3, '4': 2}
# {'3': 4, '5': 3, '4': 2}
# ```

# %% [markdown]
# ### Problem: 올바른 아이디 판별하기◼◼◻◻◻
# 😄입력받은 문자열이 올바른 아이디인지를 판별하는 is_valid_id() 함수를 정의하시오. 문자열이 알파벳과 숫자로 구성된 문자열인지 판별하는 문자열.isalnum()을 사용하셔도 좋습니다. 입출력은 함수 밖에서 이루어집니다.
#
# ```
#     올바른 아이디 조건:
#     1. 아이디는 3자 이상 15자 이하로 구성되어야 한다.
#     2. 아이디는 첫 문자와 마지막 문자가 알파벳 소문자이어야 한다.
#     3. 아이디는 알파벳 소문자, 숫자, 빼기 기호(-), 밑줄(_)만 사용할 수 있다.
#
# ```
#
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# hello-world_123
# ```
#
# Output Sample
# ```
# Input:
# True
# ```
#
# <font color='blue'>`test case-2`</font>
#
# Input Sample
# ```
# 123_abc-
# ```
#
# Output Sample
# ```
# Input:
# False
# ```

# %% [markdown]
# ### Problem: 회문 판별 문제◼◼◼◻◻
# 😄 'racecar', 'stats' '스위스' '기러기' '토마토' '인도인' '별똥별' '우영우'와 같이 앞뒤를 뒤집어도 똑같은 문자열을 회문(palindrome)이라고 합니다. 사용자로부터 문자열을 입력받고, 해당 문자열이 회문인지 아닌지를 판별하는 is_palindrome() 함수를 작성하세요. 예를 들어, "level"은 회문이므로 "회문입니다"를 출력하고, "hello"는 회문이 아니므로 "회문이 아닙니다"를 출력합니다. 단, 회문 판별 시 문자열에서 알파벳만 고려하며, 대소문자를 구분하지 않습니다. 해당 문자가 알파벳인지를 판별하는 문자열.isalpha() 메서드를 사용하셔도 좋습니다.
#
# ---
#
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# A man, a plan, a canal: Panama
# ```
#
# Output Sample
# ```
# Input:
# 회문입니다.
# ```
#
# <font color='blue'>`test case-2`</font>
#
# Input Sample
# ```
# race a car
# ```
#
# Output Sample
# ```
# Input:
# 회문이 아닙니다.
# ```

# %% [markdown]
# ## [도전 실습 문제-스스로 풀어보는 문제]

# %% [markdown]
# ### Problem: 석차 구하기◼◼◼◼◻
#
# 😄학생의 이름과 점수를 입력받습니다.
# Bob와 Ella는 같은 점수를 받았으므로, 동일한 석차를 가집니다. 이 경우, 석차는 점수가 높은 순서로 1부터 부여합니다. 학생의 석차를 구하여 딕셔너리로 반환하는 함수 calculate_ranking()를 정의하시오. 입출력은 함수밖에서 이루어집니다.
#
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# 'Alice', 'Bob', 'Charlie', 'David', 'Ella'
# 80, 90, 95, 85, 90
# ```
# Output Sample
# ```
# InputName:
# InputScore:
# Charlie: 1
# Bob: 2
# Ella: 2
# David: 4
# Alice: 5
# ```
